# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# <font size="3">Salem, MO: 1000 UTC 5 April 2022-1000 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Salem_MO.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.1006, 10.3155, 10.1071, 11.1416, 12.1396, 12.9753, 14.0362, 16.2996, 18.4561, 19.5843, 20.8296, 21.1303, 21.1251, 20.4616, 18.9046, 16.8643, 15.8607, 15.473, 16.0073, 14.4636, 11.6288, 11.1275, 10.2509, 9.68369, 8.99307]
# 25

# %%
#Air Temp CRN:
with open('CRNH0203-2022-MO_Salem_10_W.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2265:2290]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [11.3, 11.2, 11.0, 10.9, 10.9, 12.5, 15.1, 18.0, 20.3, 20.9, 20.5, 20.7, 21.1, 21.1, 20.7, 18.8, 16.0, 15.2, 17.1, 15.5, 11.9, 11.2, 10.4, 8.9, 8.1]

# %%
hour=[]
for i in range(-12,13,1):
    hour.append(i)
    i+=1
print(len(hour))
# Out:
# 25

# %%
difference_sal = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_sal.append(temp_i-temp_crn_i)

print(difference_sal)
# Out:
# [-0.1994000000000007, -0.8844999999999992, -0.8928999999999991, 0.24160000000000004, 1.2395999999999994, 0.4753000000000007, -1.0638000000000005, -1.7003999999999984, -1.8439000000000014, -1.3156999999999996, 0.3295999999999992, 0.430299999999999, 0.025099999999998346, -0.6384000000000007, -1.7954000000000008, -1.9357000000000006, -0.13930000000000042, 0.27300000000000146, -1.0927000000000007, -1.0364000000000004, -0.27120000000000033, -0.07249999999999979, -0.14910000000000068, 0.78369, 0.8930699999999998]

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_sal, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Salem_MO.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [10.8155, 10.3029, 9.42191, 10.9527, 12.2913, 12.9119, 14.1488, 16.6257, 17.561, 19.2408, 20.6596, 20.8156, 20.8443, 20.4587, 18.9689, 16.4632, 15.7736, 15.1328, 15.408, 12.9706, 11.6468, 11.1022, 10.0895, 9.23499, 8.74564]

# %%
diff3_sal = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_sal.append(temp_i-temp_crn_i)

print(diff3_sal)
# Out:
# [-0.4845000000000006, -0.8971, -1.5780899999999995, 0.05269999999999975, 1.3912999999999993, 0.41189999999999927, -0.9512, -1.3743000000000016, -2.7390000000000008, -1.6591999999999985, 0.15960000000000107, 0.11560000000000059, -0.2557000000000009, -0.6413000000000011, -1.7310999999999979, -2.3368, -0.22639999999999993, -0.0671999999999997, -1.692000000000002, -2.5294000000000008, -0.25319999999999965, -0.09779999999999944, -0.3105000000000011, 0.33498999999999945, 0.6456400000000002]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='yellow', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# salem3 = math.sqrt(MSE)
# print("RSME 3-hr 48-hr HRRR vs CRN :",salem3)

# %%
#6 hr hrrr:
with open('hrrr_f06_Salem_MO.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2260:2285]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.6253, 10.8686, 10.7066, 10.6742, 10.7714, 11.3639, 14.3728, 16.6485, 18.8097, 19.9793, 19.8139, 19.0653, 20.4948, 20.2372, 18.0611, 16.5062, 15.6348, 15.4605, 15.0092, 15.0648, 11.4448, 11.8213, 10.4033, 8.96597, 8.31467]

# %%
diff6_sal = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_sal.append(temp_i-temp_crn_i)

print(diff6_sal)
# Out:
# [0.3252999999999986, -0.3313999999999986, -0.2934000000000001, -0.22579999999999956, -0.1286000000000005, -1.1361000000000008, -0.7271999999999998, -1.3515000000000015, -1.4903000000000013, -0.9207000000000001, -0.6860999999999997, -1.6346999999999987, -0.6052, -0.8628, -2.6388999999999996, -2.293800000000001, -0.36519999999999975, 0.2605000000000004, -2.0908000000000015, -0.43520000000000003, -0.4551999999999996, 0.6213000000000015, 0.0032999999999994145, 0.06597000000000008, 0.21466999999999992]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# salem6 = math.sqrt(MSE)
# print("RSME 6-hr 48-hr HRRR vs CRN :",salem6)

# %%
#12 hr hrrr:
with open('hrrr_f12_Salem_MO.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2254:2279]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.1378, 11.6931, 10.8264, 11.2671, 12.1022, 12.3876, 15.1745, 17.8014, 18.554, 19.9215, 20.3808, 19.3252, 18.554, 18.1644, 18.0953, 16.0568, 15.631, 14.764, 14.605, 13.5642, 11.0956, 9.65137, 8.5881, 8.259, 7.63846]
# 25

# %%
diff12_sal = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_sal.append(temp_i-temp_crn_i)

print(diff12_sal)
# Out:
# [-0.16220000000000034, 0.4931000000000001, -0.17360000000000042, 0.36709999999999887, 1.2021999999999995, -0.11239999999999917, 0.07450000000000045, -0.198599999999999, -1.7460000000000022, -0.9784999999999968, -0.1191999999999993, -1.3748000000000005, -2.546000000000003, -2.935600000000001, -2.6046999999999976, -2.7432000000000016, -0.3689999999999998, -0.43599999999999994, -2.495000000000001, -1.9358000000000004, -0.8044000000000011, -1.5486299999999993, -1.8118999999999996, -0.641, -0.4615399999999994]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# salem12 = math.sqrt(MSE)
# print("RSME 12-hr 48-hr HRRR vs CRN :",salem12)

# %%
#18 hr hrrr:
with open('hrrr_f18_Salem_MO.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2248:2273]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [12.2257, 12.4848, 10.9296, 11.2658, 11.3575, 13.9343, 15.1535, 17.5877, 18.9283, 19.357, 20.2115, 20.3466, 20.2151, 20.6004, 17.9467, 16.9989, 16.8388, 15.135, 15.1592, 14.2714, 12.7885, 11.1413, 8.32669, 6.68781, 6.82211]

# %%
diff18_sal = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_sal.append(temp_i-temp_crn_i)

print(diff18_sal)
# Out:
# [0.9256999999999991, 1.2848000000000006, -0.07039999999999935, 0.3658000000000001, 0.4574999999999996, 1.4343000000000004, 0.05349999999999966, -0.41229999999999833, -1.3717000000000006, -1.5429999999999993, -0.2884999999999991, -0.3534000000000006, -0.8849000000000018, -0.49960000000000093, -2.7532999999999994, -1.8011000000000017, 0.8387999999999991, -0.0649999999999995, -1.9408000000000012, -1.2286000000000001, 0.8885000000000005, -0.058699999999999974, -2.073310000000001, -2.2121900000000005, -1.2778899999999993]

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_sal,label="1-hr")
plt.plot(hour,diff3_sal,label="3-hr")
plt.plot(hour,diff6_sal,label="6-hr")
plt.plot(hour,diff12_sal,label="12-hr")
plt.plot(hour,diff18_sal,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# salem18 = math.sqrt(MSE)
# print("RSME 18-hr 48-hr HRRR vs CRN :",salem18)

# %% [markdown]
# <font size="3">Batesville, AR: 1000 UTC 5 April 2022-1000 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Batesville_AR.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.6631, 11.878, 11.5446, 12.3916, 13.3271, 15.1628, 15.5987, 17.3621, 18.4561, 19.7093, 20.4546, 21.5053, 22.1876, 22.0866, 20.3421, 18.5518, 17.8607, 17.2855, 16.6323, 16.3386, 16.0038, 16.065, 17.1259, 13.6212, 12.6181]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-AR_Batesville_8_WNW.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2265:2290]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [11.6, 11.8, 12.1, 12.0, 12.2, 13.5, 15.5, 17.6, 18.9, 20.4, 21.8, 22.6, 22.9, 23.1, 21.9, 20.1, 18.9, 18.2, 17.5, 15.9, 16.3, 18.2, 18.5, 14.7, 12.9]

# %%
difference_bat = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_bat.append(temp_i-temp_crn_i)

print(difference_bat)
# Out:
# [0.06310000000000038, 0.0779999999999994, -0.5553999999999988, 0.3916000000000004, 1.1271000000000004, 1.6628000000000007, 0.09869999999999912, -0.23789999999999978, -0.4438999999999993, -0.6906999999999996, -1.3454000000000015, -1.0947000000000031, -0.7123999999999988, -1.0134000000000007, -1.5579, -1.5482000000000014, -1.0392999999999972, -0.9145000000000003, -0.8676999999999992, 0.4385999999999992, -0.29620000000000246, -2.134999999999998, -1.3740999999999985, -1.0787999999999993, -0.28190000000000026]

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_bat, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# batesville1 = math.sqrt(MSE)
# print("RSME 1-hr 48-hr HRRR vs CRN :",batesville1)

# %%
#3 hr hrrr:
with open('hrrr_f03_Batesville_AR.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.3155, 10.9904, 11.3594, 11.7652, 12.4163, 14.8494, 16.5238, 16.6882, 16.811, 17.4908, 19.5971, 20.8156, 21.4068, 21.2712, 19.7189, 17.9632, 17.2111, 16.7578, 16.408, 16.2831, 16.3968, 16.5397, 16.4645, 13.5475, 12.9331]

# %%
diff3_bat = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_bat.append(temp_i-temp_crn_i)

print(diff3_bat)
# Out:
# [-0.28449999999999953, -0.8096000000000014, -0.7405999999999988, -0.2347999999999999, 0.21630000000000038, 1.3493999999999993, 1.0238000000000014, -0.911800000000003, -2.0889999999999986, -2.9091999999999985, -2.2028999999999996, -1.7844000000000015, -1.493199999999998, -1.828800000000001, -2.181099999999997, -2.136800000000001, -1.6889000000000003, -1.4421999999999997, -1.0919999999999987, 0.38310000000000066, 0.09679999999999822, -1.6602999999999994, -2.035499999999999, -1.1524999999999999, 0.03309999999999924]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# batesville3 = math.sqrt(MSE)
# print("RSME 3-hr 48-hr HRRR vs CRN :",batesville3)

# %%
#6 hr hrrr:
with open('hrrr_f06_Batesville_AR.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2260:2285]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [12.0628, 11.3686, 10.8941, 11.6742, 12.2089, 13.6764, 15.6228, 15.086, 17.3722, 19.9168, 19.6889, 19.1278, 19.5573, 19.9872, 18.8111, 17.1937, 16.5098, 16.0855, 15.8842, 15.7523, 15.8823, 16.0713, 16.2158, 14.1535, 12.5022]

# %%
diff6_bat = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_bat.append(temp_i-temp_crn_i)

print(diff6_bat)
# Out:
# [0.46279999999999966, -0.4314, -1.2058999999999997, -0.3257999999999992, 0.008900000000000574, 0.17639999999999922, 0.1227999999999998, -2.514000000000001, -1.5277999999999992, -0.4832000000000001, -2.1111000000000004, -3.472200000000001, -3.342699999999997, -3.1128, -3.088899999999999, -2.9063000000000017, -2.3902, -2.1144999999999996, -1.6158000000000001, -0.1477000000000004, -0.41769999999999996, -2.1286999999999985, -2.2841999999999985, -0.5465, -0.39780000000000015]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# batesville6 = math.sqrt(MSE)
# print("RSME 6-hr 48-hr HRRR vs CRN :",batesville6)

# %%
#12 hr hrrr:
with open('hrrr_f12_Batesville_AR.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2254:2279]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.2628, 11.6306, 10.9514, 11.5171, 13.7272, 15.3876, 15.6745, 18.6139, 18.4915, 19.234, 20.2558, 19.5752, 19.679, 18.1644, 18.3453, 16.4943, 16.1935, 16.139, 15.5425, 15.9392, 16.0956, 15.9639, 16.3381, 12.8215, 11.7635]
# 25

# %%
diff12_bat = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_bat.append(temp_i-temp_crn_i)

print(diff12_bat)
# Out:
# [-0.3371999999999993, -0.16940000000000133, -1.1486, -0.4829000000000008, 1.5272000000000006, 1.8876000000000008, 0.1745000000000001, 1.0138999999999996, -0.4085000000000001, -1.1659999999999968, -1.5442, -3.0248000000000026, -3.221, -4.935600000000001, -3.554699999999997, -3.6057000000000023, -2.7064999999999984, -2.061, -1.9574999999999996, 0.039199999999999235, -0.2043999999999997, -2.2360999999999986, -2.1618999999999993, -1.878499999999999, -1.1364999999999998]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# batesville12 = math.sqrt(MSE)
# print("RSME 12-hr 48-hr HRRR vs CRN :",batesville12)

# %%
#18 hr hrrr:
with open('hrrr_f18_Batesville_AR.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2248:2273]

    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [12.9757, 12.7348, 12.3671, 12.8908, 13.2325, 16.1843, 16.6535, 18.7752, 20.1158, 21.357, 21.774, 20.7216, 20.7776, 21.2879, 18.8842, 16.8739, 16.0888, 15.0725, 14.5967, 14.7089, 15.601, 14.5163, 15.1392, 11.9378, 11.6346]

# %%
diff18_bat = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_bat.append(temp_i-temp_crn_i)

print(diff18_bat)
# Out:
# [1.3757000000000001, 0.9347999999999992, 0.267100000000001, 0.8908000000000005, 1.0325000000000006, 2.6843000000000004, 1.153500000000001, 1.1752000000000002, 1.2158000000000015, 0.9570000000000007, -0.0259999999999998, -1.8784000000000027, -2.122399999999999, -1.812100000000001, -3.0157999999999987, -3.2261000000000024, -2.8111999999999995, -3.1274999999999995, -2.9032999999999998, -1.1911000000000005, -0.6989999999999998, -3.6837, -3.3607999999999993, -2.7622, -1.2653999999999996]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# batesville18 = math.sqrt(MSE)
# print("RSME 18-hr 48-hr HRRR vs CRN :",batesville18)

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_bat,label="1-hr")
plt.plot(hour,diff3_bat,label="3-hr")
plt.plot(hour,diff6_bat,label="6-hr")
plt.plot(hour,diff12_bat,label="12-hr")
plt.plot(hour,diff18_bat,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Lafayette, LA: 1000 UTC 5 April 2022-1000 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Lafayette_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.2256, 22.628, 22.4821, 22.6416, 22.6396, 22.9753, 24.2237, 23.4246, 25.0811, 25.3343, 25.0796, 26.1303, 25.5001, 25.7116, 23.9671, 23.5518, 22.7982, 22.6605, 22.4448, 22.8386, 22.4413, 22.6275, 22.5634, 22.8712, 22.9931]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-LA_Lafayette_13_SE.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2265:2290]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [22.0, 22.2, 22.6, 22.5, 22.8, 23.5, 24.2, 25.3, 25.5, 25.5, 25.7, 25.9, 25.9, 25.4, 24.7, 23.4, 23.0, 23.0, 23.1, 23.2, 23.2, 23.3, 23.4, 23.4, 23.5]

# %%
difference_laf = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_laf.append(temp_i-temp_crn_i)

print(difference_laf)
# Out:
# [0.22560000000000002, 0.4280000000000008, -0.11790000000000234, 0.1416000000000004, -0.1603999999999992, -0.5246999999999993, 0.02370000000000161, -1.875399999999999, -0.4189000000000007, -0.16570000000000107, -0.6204000000000001, 0.23029999999999973, -0.3998999999999988, 0.3116000000000021, -0.7329000000000008, 0.1518000000000015, -0.20179999999999865, -0.339500000000001, -0.6552000000000007, -0.3613999999999997, -0.758700000000001, -0.6724999999999994, -0.8365999999999971, -0.5287999999999968, -0.5069000000000017]

# %%
# hour=[]
# for i in range(-15,16,1):
#     hour.append(i)
#     i+=1
# print(len(hour))

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_laf, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
lafayette1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",lafayette1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 0.5839541982039343

# %%
#3 hr hrrr:
with open('hrrr_f03_Lafayette_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.0655, 22.7404, 22.5469, 22.8902, 23.3538, 23.0994, 23.5863, 24.6257, 25.9985, 24.8658, 25.9721, 26.0656, 25.7818, 24.6462, 24.0939, 23.4632, 22.9611, 23.0078, 22.408, 22.5331, 22.7093, 22.7897, 22.277, 22.235, 22.0581]

# %%
diff3_laf = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_laf.append(temp_i-temp_crn_i)

print(diff3_laf)
# Out:
# [0.06550000000000011, 0.5404000000000018, -0.05310000000000059, 0.3902000000000001, 0.553799999999999, -0.40060000000000073, -0.6136999999999979, -0.6743000000000023, 0.49849999999999994, -0.6341999999999999, 0.2721000000000018, 0.1656000000000013, -0.11819999999999808, -0.7537999999999982, -0.6060999999999979, 0.06320000000000192, -0.03890000000000171, 0.007799999999999585, -0.6920000000000002, -0.6668999999999983, -0.49070000000000036, -0.5103000000000009, -1.1229999999999976, -1.1649999999999991, -1.4419000000000004]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
lafayette3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",lafayette3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 0.6190123643353174

# %%
#6 hr hrrr:
with open('hrrr_f06_Lafayette_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2260:2285]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.5628, 22.5561, 22.5816, 22.8617, 23.5839, 24.6764, 24.8728, 25.6485, 25.3097, 26.5418, 26.1889, 25.8778, 25.5573, 25.0497, 23.8111, 22.6937, 22.5098, 22.2105, 22.4467, 22.1898, 22.6948, 22.1338, 22.4658, 22.716, 22.6272]

# %%
diff6_laf = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_laf.append(temp_i-temp_crn_i)

print(diff6_laf)
# Out:
# [0.5627999999999993, 0.3561000000000014, -0.01839999999999975, 0.361699999999999, 0.7838999999999992, 1.176400000000001, 0.6728000000000023, 0.3484999999999978, -0.19030000000000058, 1.0417999999999985, 0.488900000000001, -0.022199999999998, -0.3426999999999971, -0.35029999999999717, -0.8888999999999996, -0.7062999999999988, -0.4902000000000015, -0.7895000000000003, -0.6533000000000015, -1.0101999999999975, -0.5051999999999985, -1.1662, -0.934199999999997, -0.6839999999999975, -0.8728000000000016]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
lafayette6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",lafayette6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 0.6947230987954837

# %%
#12 hr hrrr:
with open('hrrr_f12_Lafayette_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2254:2279]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.3253, 22.3181, 22.3264, 22.4546, 23.0397, 23.3251, 25.2995, 25.8639, 26.4915, 27.109, 28.6933, 28.4502, 26.2415, 25.6019, 24.1578, 22.4943, 21.6935, 22.139, 21.9175, 22.3142, 22.0331, 21.7139, 21.8381, 21.8215, 21.951]
# 25

# %%
diff12_laf = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_laf.append(temp_i-temp_crn_i)

print(diff12_laf)
# Out:
# [0.3252999999999986, 0.11810000000000187, -0.27360000000000184, -0.04540000000000077, 0.23969999999999914, -0.17490000000000094, 1.099499999999999, 0.5639000000000003, 0.9914999999999985, 1.6090000000000018, 2.9933000000000014, 2.5502000000000002, 0.3414999999999999, 0.20190000000000197, -0.5421999999999976, -0.9056999999999995, -1.3064999999999998, -0.8610000000000007, -1.182500000000001, -0.8857999999999997, -1.1668999999999983, -1.5861000000000018, -1.5618999999999978, -1.5784999999999982, -1.5489999999999995]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
lafayette12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",lafayette12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 1.2321975096550066

# %%
#18 hr hrrr:
with open('hrrr_f18_Lafayette_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2248:2273]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.2882, 21.9223, 21.9921, 22.2658, 23.545, 23.6218, 23.591, 23.5252, 25.3033, 26.857, 29.5865, 28.1591, 27.4026, 25.9754, 24.5717, 23.0614, 21.7138, 21.3225, 21.2842, 21.9589, 21.601, 21.3913, 22.1392, 22.0003, 21.9471]

# %%
diff18_laf = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_laf.append(temp_i-temp_crn_i)

print(diff18_laf)
# Out:
# [0.2881999999999998, -0.2776999999999994, -0.6079000000000008, -0.2342000000000013, 0.745000000000001, 0.12180000000000035, -0.6089999999999982, -1.774799999999999, -0.19669999999999987, 1.3569999999999993, 3.8865000000000016, 2.2591, 1.502600000000001, 0.5754000000000019, -0.12829999999999941, -0.33859999999999957, -1.286200000000001, -1.6774999999999984, -1.815800000000003, -1.2410999999999994, -1.5990000000000002, -1.9086999999999996, -1.2607999999999997, -1.3996999999999993, -1.552900000000001]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
lafayette18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",lafayette18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.4275821510512103

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_sal,label="1-hr")
plt.plot(hour,diff3_laf,label="3-hr")
plt.plot(hour,diff6_laf,label="6-hr")
plt.plot(hour,diff12_laf,label="12-hr")
plt.plot(hour,diff18_laf,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Monroe, LA: 1000 UTC 5 April 2022-1000 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Monroe_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [17.9756, 17.253, 17.3571, 17.2041, 17.3271, 18.0378, 18.9737, 20.4246, 21.9561, 23.0218, 24.4546, 25.5678, 26.0626, 26.2116, 25.7796, 23.9893, 22.4232, 21.723, 21.7573, 22.0886, 22.1288, 22.44, 22.6884, 21.9337, 21.7431]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-LA_Monroe_26_N.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2265:2290]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [17.2, 16.2, 16.1, 16.0, 16.3, 16.9, 18.2, 21.1, 23.5, 25.6, 26.9, 28.1, 28.7, 28.6, 26.4, 22.1, 20.1, 20.8, 22.7, 22.8, 22.6, 22.5, 22.5, 22.5, 22.4]

# %%
difference_mon = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_mon.append(temp_i-temp_crn_i)

print(difference_mon)
# Out:
# [0.7756000000000007, 1.0530000000000008, 1.2570999999999977, 1.2041000000000004, 1.0271000000000008, 1.1378000000000021, 0.7737000000000016, -0.6753999999999998, -1.5439000000000007, -2.5782000000000025, -2.4453999999999994, -2.532200000000003, -2.6373999999999995, -2.3884000000000007, -0.6204000000000001, 1.8892999999999986, 2.3232, 0.9229999999999983, -0.9426999999999985, -0.7114000000000011, -0.47120000000000317, -0.05999999999999872, 0.18840000000000146, -0.5662999999999982, -0.6569000000000003]

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_mon, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
monroe1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",monroe1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.4810747974359704

# %%
#3 hr hrrr:
with open('hrrr_f03_Monroe_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.378, 19.1154, 18.0469, 17.3277, 18.1663, 17.6619, 19.7113, 20.5632, 21.3735, 22.9283, 23.8471, 24.7531, 25.4068, 25.2087, 24.5314, 23.0882, 22.5861, 22.5703, 21.9705, 21.9706, 21.8343, 21.6647, 22.152, 22.1725, 22.2456]

# %%
diff3_mon = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_mon.append(temp_i-temp_crn_i)

print(diff3_mon)
# Out:
# [1.1780000000000008, 2.9154000000000018, 1.9468999999999994, 1.3277, 1.866299999999999, 0.7619000000000007, 1.511300000000002, -0.536800000000003, -2.1265, -2.6717000000000013, -3.0528999999999975, -3.3469000000000015, -3.293199999999999, -3.391300000000001, -1.8685999999999972, 0.9881999999999991, 2.486099999999997, 1.7702999999999989, -0.729499999999998, -0.8293999999999997, -0.7657000000000025, -0.8353000000000002, -0.347999999999999, -0.32750000000000057, -0.15439999999999898]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
monroe3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",monroe3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.9302161296600957

# %%
#6 hr hrrr:
with open('hrrr_f06_Monroe_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2260:2285]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.0628, 19.8686, 16.8941, 19.6117, 19.3964, 19.7389, 20.3103, 21.586, 22.1847, 23.1668, 23.6264, 23.8778, 24.6823, 24.4247, 23.4986, 22.1312, 21.5098, 21.898, 22.0717, 22.1898, 21.8823, 21.8213, 21.5908, 21.6535, 21.5022]

# %%
diff6_mon = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_mon.append(temp_i-temp_crn_i)

print(diff6_mon)
# Out:
# [0.8628, 3.6686000000000014, 0.7941000000000003, 3.611699999999999, 3.096399999999999, 2.8389000000000024, 2.1103000000000023, 0.4859999999999971, -1.3153000000000006, -2.433200000000003, -3.2735999999999983, -4.222200000000001, -4.017699999999998, -4.1753, -2.901399999999999, 0.03119999999999834, 1.409799999999997, 1.097999999999999, -0.6282999999999994, -0.610199999999999, -0.7177000000000007, -0.6786999999999992, -0.9091999999999985, -0.8464999999999989, -0.8978000000000002]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
monroe6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",monroe6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 2.3297029711961135

# %%
#12 hr hrrr:
with open('hrrr_f12_Monroe_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2254:2279]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.3878, 17.6306, 17.3264, 17.3921, 17.8522, 19.2001, 21.2995, 21.4889, 22.8665, 24.5465, 24.1308, 24.8877, 25.3665, 24.5394, 23.9078, 22.2443, 21.381, 20.4515, 20.9175, 20.6892, 20.5956, 21.5264, 21.7131, 21.5715, 21.3885]
# 25

# %%
diff12_mon = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_mon.append(temp_i-temp_crn_i)

print(diff12_mon)
# Out:
# [1.1877999999999993, 1.4306000000000019, 1.2263999999999982, 1.3920999999999992, 1.5521999999999991, 2.3001000000000005, 3.099499999999999, 0.3888999999999996, -0.6335000000000015, -1.0534999999999997, -2.769199999999998, -3.2123000000000026, -3.333500000000001, -4.060600000000001, -2.492199999999997, 0.14429999999999765, 1.2809999999999988, -0.34850000000000136, -1.7824999999999989, -2.110800000000001, -2.0044000000000004, -0.9736000000000011, -0.7868999999999993, -0.9284999999999997, -1.011499999999998]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
monroe12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",monroe12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 1.9447743706661706

# %%
#18 hr hrrr:
with open('hrrr_f18_Monroe_LA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2248:2273]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.6632, 17.1098, 17.7421, 18.0783, 17.1075, 17.9968, 19.2785, 20.0252, 21.7408, 23.4195, 25.274, 25.4716, 25.5276, 25.4754, 24.3217, 22.6239, 21.2138, 21.385, 20.7217, 21.5839, 21.5385, 21.5163, 21.0142, 20.8753, 20.5721]

# %%
diff18_mon = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_mon.append(temp_i-temp_crn_i)

print(diff18_mon)
# Out:
# [1.4632000000000005, 0.9098000000000006, 1.6420999999999992, 2.0782999999999987, 0.807500000000001, 1.0968000000000018, 1.0785000000000018, -1.0747999999999998, -1.7591999999999999, -2.180500000000002, -1.6259999999999977, -2.6284000000000027, -3.1723999999999997, -3.124600000000001, -2.0782999999999987, 0.5238999999999976, 1.1137999999999977, 0.5850000000000009, -1.9783000000000008, -1.2161000000000008, -1.0615000000000023, -0.9836999999999989, -1.4858000000000011, -1.6247000000000007, -1.8278999999999996]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
monroe18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",monroe18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.7115950157674569

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_mon,label="1-hr")
plt.plot(hour,diff3_mon,label="3-hr")
plt.plot(hour,diff6_mon,label="6-hr")
plt.plot(hour,diff12_mon,label="12-hr")
plt.plot(hour,diff18_mon,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Holly Springs, MS: 1100 UTC 5 April 2022-1100 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Holly Springs_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2266:2291]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [14.0655, 13.9196, 14.2041, 13.8271, 14.6003, 14.4737, 15.4246, 15.8311, 17.7093, 17.3296, 18.6928, 19.3126, 19.4616, 18.7796, 17.4268, 16.2982, 15.348, 15.1323, 14.5886, 14.6913, 14.8775, 15.1884, 16.9962, 18.5556, 19.0258]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-MS_Holly_Springs_4_N.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2266:2291]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [12.6, 12.6, 12.8, 13.2, 13.0, 13.2, 13.6, 14.7, 16.0, 17.1, 18.4, 19.7, 20.3, 19.2, 15.5, 14.2, 14.6, 14.8, 14.5, 14.4, 14.0, 13.7, 15.2, 16.2, 17.0]

# %%
difference_hol = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_hol.append(temp_i-temp_crn_i)

print(difference_hol)
# Out:
# [1.4655000000000005, 1.3196000000000012, 1.4040999999999997, 0.6271000000000004, 1.6003000000000007, 1.2736999999999998, 1.8246000000000002, 1.1311, 1.709299999999999, 0.2295999999999978, 0.2927999999999997, -0.3873999999999995, -0.8384, -0.4204000000000008, 1.9268, 2.098200000000002, 0.7480000000000011, 0.33230000000000004, 0.08859999999999957, 0.29129999999999967, 0.8774999999999995, 1.4884000000000004, 1.7962000000000025, 2.355599999999999, 2.0258000000000003]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
holly1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",holly1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.3248021802518293

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_hol, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Holly Springs_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2264:2289]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [14.9279, 13.7344, 13.4527, 13.7913, 15.1619, 15.0863, 16.1257, 16.061, 16.3033, 17.4721, 17.3781, 17.8443, 18.2712, 17.6564, 16.1507, 15.7111, 15.3828, 14.8455, 14.2831, 14.3968, 14.1647, 14.902, 16.36, 17.8081, 19.2788]

# %%
diff3_hol = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_hol.append(temp_i-temp_crn_i)

print(diff3_hol)
# Out:
# [2.3278999999999996, 1.1344000000000012, 0.6526999999999994, 0.5913000000000004, 2.1618999999999993, 1.8863000000000003, 2.5256999999999987, 1.3610000000000007, 0.3033000000000001, 0.37209999999999965, -1.0218999999999987, -1.8556999999999988, -2.0288000000000004, -1.5435999999999979, 0.6507000000000005, 1.5111000000000008, 0.7827999999999999, 0.045499999999998764, -0.21690000000000076, -0.0031999999999996476, 0.16469999999999985, 1.202, 1.1600000000000001, 1.6081000000000003, 2.2788000000000004]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
holly3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",holly3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.4018176503383026

# %%
#6 hr hrrr:
with open('hrrr_f06_Holly Springs_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2261:2286]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [13.6186, 13.5816, 13.2367, 13.5839, 14.3014, 13.4353, 14.7735, 15.5597, 15.6668, 18.0014, 17.9403, 18.1198, 17.7997, 17.0611, 15.5687, 14.9473, 14.9605, 14.8217, 14.7523, 14.5073, 14.5088, 15.4033, 16.0285, 16.6272, 17.455]

# %%
diff6_hol = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_hol.append(temp_i-temp_crn_i)

print(diff6_hol)
# Out:
# [1.018600000000001, 0.9816000000000003, 0.4367000000000001, 0.3839000000000006, 1.3013999999999992, 0.2353000000000005, 1.1735000000000007, 0.8597000000000001, -0.3331999999999997, 0.9013999999999989, -0.459699999999998, -1.5801999999999978, -2.5002999999999993, -2.1388999999999996, 0.06869999999999976, 0.747300000000001, 0.36050000000000004, 0.021699999999999164, 0.25229999999999997, 0.1073000000000004, 0.5088000000000008, 1.7033000000000005, 0.8285000000000018, 0.42719999999999914, 0.4549999999999983]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
holly6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",holly6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 1.013261679133283

# %%
#12 hr hrrr:
with open('hrrr_f12_Holly Springs_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2255:2280]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [14.8806, 13.3264, 13.2046, 14.0397, 14.5751, 14.1745, 14.3639, 16.2415, 17.234, 18.9433, 17.6377, 17.6165, 17.2894, 17.0953, 16.8693, 16.256, 15.639, 14.23, 13.9392, 14.5956, 15.2764, 15.7131, 16.8215, 17.8885, 18.1015]
# 25

# %%
diff12_hol = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_hol.append(temp_i-temp_crn_i)

print(diff12_hol)
# Out:
# [2.2805999999999997, 0.7263999999999999, 0.4045999999999985, 0.8397000000000006, 1.5751000000000008, 0.9745000000000008, 0.7638999999999996, 1.5414999999999992, 1.2340000000000018, 1.8432999999999993, -0.7622999999999998, -2.083500000000001, -3.0106, -2.1046999999999976, 1.369299999999999, 2.056000000000001, 1.0389999999999997, -0.5700000000000003, -0.5608000000000004, 0.19559999999999889, 1.2764000000000006, 2.0131000000000014, 1.621500000000001, 1.6885000000000012, 1.1015000000000015]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
holly12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",holly12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 1.5041099159303486

# %%
#18 hr hrrr:
with open('hrrr_f18_Holly Springs_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2249:2274]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [13.4223, 14.1171, 13.7033, 13.6075, 14.4968, 13.7785, 14.2127, 15.8033, 17.482, 17.8365, 17.9091, 18.7776, 18.1004, 17.8842, 16.1239, 15.6513, 14.3225, 13.9092, 14.1464, 14.351, 14.5163, 15.2642, 15.8128, 16.3846, 17.2332]

# %%
diff18_hol = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_hol.append(temp_i-temp_crn_i)

print(diff18_hol)
# Out:
# [0.8223000000000003, 1.517100000000001, 0.9032999999999998, 0.40750000000000064, 1.4968000000000004, 0.5785, 0.6127000000000002, 1.1033000000000008, 1.4819999999999993, 0.7364999999999995, -0.4908999999999999, -0.9223999999999997, -2.1996, -1.3157999999999994, 0.623899999999999, 1.4513000000000016, -0.27749999999999986, -0.8908000000000005, -0.35360000000000014, -0.04899999999999949, 0.5162999999999993, 1.5642000000000014, 0.6128, 0.18459999999999965, 0.23320000000000007]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
holly18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",holly18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.0039603667476125

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_sal,label="1-hr")
plt.plot(hour,diff3_hol,label="3-hr")
plt.plot(hour,diff6_hol,label="6-hr")
plt.plot(hour,diff12_hol,label="12-hr")
plt.plot(hour,diff18_hol,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Newton, MS: 1100 UTC 5 April 2022-1100 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Newton_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2266:2291]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.378, 19.2946, 20.3291, 21.0771, 21.6628, 19.2862, 19.7371, 21.1436, 22.2718, 23.2671, 23.8178, 23.4376, 23.2741, 21.1546, 20.5518, 20.1107, 19.848, 19.4448, 19.8386, 20.1288, 20.5025, 20.9384, 21.4962, 21.7431, 22.0883]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-MS_Newton_5_ENE.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2266:2291]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [16.2, 18.1, 18.8, 18.0, 18.0, 17.5, 17.6, 20.0, 22.1, 23.2, 24.3, 24.3, 23.6, 22.0, 20.4, 19.7, 19.5, 19.5, 19.7, 19.6, 19.7, 20.4, 21.0, 21.3, 21.7]

# %%
difference_new = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_new.append(temp_i-temp_crn_i)

print(difference_new)
# Out:
# [2.178000000000001, 1.1945999999999977, 1.5290999999999997, 3.0771000000000015, 3.6628000000000007, 1.786200000000001, 2.1371, 1.1435999999999993, 0.1717999999999975, 0.06709999999999994, -0.4822000000000024, -0.8624000000000009, -0.32590000000000074, -0.8454000000000015, 0.1518000000000015, 0.41070000000000206, 0.347999999999999, -0.05519999999999925, 0.13860000000000028, 0.5287999999999968, 0.802500000000002, 0.5384000000000029, 0.49620000000000175, 0.4430999999999976, 0.388300000000001]

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_new, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonms1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",newtonms1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.333149266511444

# %%
#3 hr hrrr:
with open('hrrr_f03_Newton_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2264:2289]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.8029, 19.5469, 20.7027, 19.9163, 22.4119, 22.0238, 21.3132, 21.436, 22.4908, 23.4721, 23.7531, 23.3443, 22.5837, 21.2189, 20.4632, 19.5861, 19.2578, 19.408, 19.7206, 20.0218, 19.9772, 20.2145, 20.6725, 21.4331, 21.4038]

# %%
diff3_new = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_new.append(temp_i-temp_crn_i)

print(diff3_new)
# Out:
# [2.6029000000000018, 1.4468999999999994, 1.9026999999999994, 1.9162999999999997, 4.411899999999999, 4.523800000000001, 3.713199999999997, 1.436, 0.3907999999999987, 0.2721000000000018, -0.5469000000000008, -0.9557000000000002, -1.016300000000001, -0.7810999999999986, 0.06320000000000192, -0.113900000000001, -0.24220000000000041, -0.09199999999999875, 0.020600000000001728, 0.4217999999999975, 0.27720000000000056, -0.18549999999999756, -0.32750000000000057, 0.13309999999999889, -0.2961999999999989]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonms3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",newtonms3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.7390716560280086

# %%
#6 hr hrrr:
with open('hrrr_f06_Newton_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2261:2286]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [19.4936, 20.2691, 21.0492, 20.3964, 20.5514, 21.3728, 21.7735, 23.9972, 23.2293, 23.2514, 23.2528, 23.5573, 22.7997, 21.0611, 20.3187, 19.2598, 19.2105, 19.0717, 19.3773, 20.1948, 19.9463, 19.9658, 20.4035, 20.1897, 21.1425]

# %%
diff6_new = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_new.append(temp_i-temp_crn_i)

print(diff6_new)
# Out:
# [3.2936000000000014, 2.1691000000000003, 2.2491999999999983, 2.3964, 2.551400000000001, 3.8728000000000016, 4.173499999999997, 3.9971999999999994, 1.129299999999997, 0.051400000000001, -1.0472000000000001, -0.7426999999999992, -0.8003, -0.9389000000000003, -0.08129999999999882, -0.4402000000000008, -0.2895000000000003, -0.4283000000000001, -0.32269999999999754, 0.5947999999999993, 0.24630000000000152, -0.43419999999999703, -0.5964999999999989, -1.1103000000000023, -0.557500000000001]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonms6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",newtonms6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 1.8844702519275807

# %%
#12 hr hrrr:
with open('hrrr_f12_Newton_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2255:2280]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.1306, 19.2014, 20.6421, 17.2272, 17.3876, 18.0495, 22.2389, 20.929, 23.7965, 24.0058, 23.6377, 23.429, 22.9769, 21.8453, 21.0568, 19.6935, 19.514, 18.73, 19.1892, 17.4081, 19.2139, 19.5256, 20.1965, 20.7635, 20.664]
# 25

# %%
diff12_new = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_new.append(temp_i-temp_crn_i)

print(diff12_new)
# Out:
# [1.9306000000000019, 1.1013999999999982, 1.8420999999999985, -0.7728000000000002, -0.6124000000000009, 0.5494999999999983, 4.6389, 0.9289999999999985, 1.6965000000000003, 0.8058000000000014, -0.6623000000000019, -0.8710000000000022, -0.6231000000000009, -0.15469999999999828, 0.6568000000000005, -0.006499999999999062, 0.013999999999999346, -0.7699999999999996, -0.5107999999999997, -2.1919000000000004, -0.4861000000000004, -0.8743999999999978, -0.8034999999999997, -0.5365000000000002, -1.0359999999999978]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonms12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",newtonms12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 1.3597740765288915

# %%
#18 hr hrrr:
with open('hrrr_f18_Newton_MS.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2249:2274]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [17.3598, 18.9921, 19.9533, 20.17, 21.3718, 19.591, 20.7127, 21.1158, 22.732, 23.274, 22.9091, 22.5901, 23.4754, 20.8217, 19.8114, 19.5888, 18.9475, 19.0967, 18.6464, 19.476, 20.0788, 20.0142, 19.6253, 20.1971, 20.2332]

# %%
diff18_new = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_new.append(temp_i-temp_crn_i)

print(diff18_new)
# Out:
# [1.1598000000000006, 0.8920999999999992, 1.153299999999998, 2.1700000000000017, 3.3718000000000004, 2.091000000000001, 3.1127000000000002, 1.1158000000000001, 0.6319999999999979, 0.07400000000000162, -1.390900000000002, -1.709900000000001, -0.12460000000000093, -1.1783000000000001, -0.5885999999999996, -0.11120000000000019, -0.5524999999999984, -0.40330000000000155, -1.0535999999999994, -0.12400000000000233, 0.3788000000000018, -0.3857999999999997, -1.3747000000000007, -1.1029000000000018, -1.4667999999999992]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonms18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",newtonms18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.4003510517009659

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_new,label="1-hr")
plt.plot(hour,diff3_new,label="3-hr")
plt.plot(hour,diff6_new,label="6-hr")
plt.plot(hour,diff12_new,label="12-hr")
plt.plot(hour,diff18_new,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Gainesville, AL: 1300 UTC 5 April 2022-1300 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Gainesville_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [17.1416, 16.0146, 16.9753, 19.7862, 20.2996, 19.7686, 21.8343, 20.8296, 23.0053, 23.3751, 23.5866, 20.7171, 19.5518, 18.7982, 18.473, 18.6948, 19.2136, 19.5663, 19.7525, 20.0634, 20.4962, 20.7431, 21.2133, 21.6693, 22.4179]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-AL_Gainesville_2_NE.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2268:2293]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [15.6, 16.0, 16.1, 17.5, 17.9, 19.3, 21.1, 23.5, 25.0, 25.6, 25.0, 23.6, 21.4, 20.0, 19.1, 18.4, 18.4, 19.0, 19.0, 19.5, 20.0, 20.2, 20.3, 20.6, 21.1]

# %%
difference_gai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_gai.append(temp_i-temp_crn_i)

print(difference_gai)
# Out:
# [1.5416000000000007, 0.0146000000000015, 0.8752999999999993, 2.286200000000001, 2.399600000000003, 0.4685999999999986, 0.7342999999999975, -2.6704000000000008, -1.9947000000000017, -2.2249000000000017, -1.4133999999999993, -2.882900000000003, -1.8481999999999985, -1.2017999999999986, -0.6270000000000024, 0.29480000000000217, 0.813600000000001, 0.5662999999999982, 0.7525000000000013, 0.5634000000000015, 0.49620000000000175, 0.543099999999999, 0.9132999999999996, 1.0692999999999984, 1.317899999999998]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gainesville1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",gainesville1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.4521348960754306

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_gai, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Gainesville_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2266:2291]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [16.5152, 17.3538, 18.7869, 19.7738, 22.7507, 23.2485, 21.6783, 21.6596, 23.1281, 22.9068, 22.4587, 21.4689, 20.0882, 18.5236, 18.6953, 18.0955, 18.1581, 18.1468, 18.4147, 19.5895, 19.985, 20.4331, 20.6538, 21.1037, 21.6616]

# %%
diff3_gai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_gai.append(temp_i-temp_crn_i)

print(diff3_gai)
# Out:
# [0.9152000000000005, 1.3537999999999997, 2.686899999999998, 2.2738000000000014, 4.8507, 3.9484999999999992, 0.5782999999999987, -1.840399999999999, -1.8719000000000001, -2.693200000000001, -2.5412999999999997, -2.1311, -1.311799999999998, -1.4764000000000017, -0.40470000000000184, -0.30449999999999733, -0.24189999999999756, -0.8532000000000011, -0.5853000000000002, 0.08950000000000102, -0.015000000000000568, 0.2331000000000003, 0.35379999999999967, 0.5036999999999985, 0.5615999999999985]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gainesville3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",gainesville3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.8515022236011491

# %%
#6 hr hrrr:
with open('hrrr_f06_Gainesville_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [17.7992, 17.6464, 18.4264, 21.4978, 20.961, 21.7472, 23.3543, 23.1889, 22.8153, 22.6823, 22.0497, 21.2486, 20.3187, 20.2598, 18.398, 18.3842, 17.9398, 18.6323, 17.8213, 18.4033, 18.966, 19.1897, 20.08, 20.6186, 21.5708]

# %%
diff6_gai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_gai.append(temp_i-temp_crn_i)

print(diff6_gai)
# Out:
# [2.1991999999999994, 1.6463999999999999, 2.3263999999999996, 3.9978000000000016, 3.061, 2.4471999999999987, 2.254299999999997, -0.3110999999999997, -2.1846999999999994, -2.9177, -2.9502999999999986, -2.3514000000000017, -1.0812999999999988, 0.2597999999999985, -0.7020000000000017, -0.015799999999998704, -0.46019999999999683, -0.36769999999999925, -1.1786999999999992, -1.0966999999999985, -1.033999999999999, -1.0103000000000009, -0.22000000000000242, 0.018599999999999284, 0.470799999999997]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gainesville6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",gainesville6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 1.8333264558174027

# %%
#12 hr hrrr:
with open('hrrr_f12_Gainesville_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2257:2282]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [18.5171, 19.0397, 18.0126, 17.612, 19.2389, 20.554, 23.1715, 24.8808, 23.3252, 22.804, 22.7894, 22.4703, 21.0568, 19.6935, 20.2015, 19.1675, 18.0642, 17.2206, 17.5264, 18.5256, 18.509, 19.576, 19.789, 20.3433, 20.8504]
# 25

# %%
diff12_gai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_gai.append(temp_i-temp_crn_i)

print(diff12_gai)
# Out:
# [2.9170999999999996, 3.0397, 1.9125999999999976, 0.11199999999999832, 1.3389000000000024, 1.2539999999999978, 2.0715000000000003, 1.3808000000000007, -1.6748000000000012, -2.796000000000003, -2.2105999999999995, -1.1296999999999997, -0.3431999999999995, -0.3064999999999998, 1.101499999999998, 0.7675000000000018, -0.335799999999999, -1.779399999999999, -1.4736000000000011, -0.9743999999999993, -1.4909999999999997, -0.6239999999999988, -0.5109999999999992, -0.25670000000000215, -0.24960000000000093]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gainesville12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",gainesville12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 1.5386241283692388

# %%
#18 hr hrrr:
with open('hrrr_f18_Gainesville_AL (1).txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2251:2276]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [17.2033, 17.2325, 19.7468, 21.966, 19.7752, 21.2408, 21.4195, 22.4615, 22.7216, 22.4026, 22.6629, 20.9467, 20.1864, 20.2138, 18.51, 18.8467, 18.7089, 18.5385, 18.5163, 18.3267, 17.5628, 19.7596, 19.8582, 19.9752, 21.0109]

# %%
diff18_gai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_gai.append(temp_i-temp_crn_i)

print(diff18_gai)
# Out:
# [1.603299999999999, 1.2325000000000017, 3.646799999999999, 4.466000000000001, 1.875200000000003, 1.9407999999999994, 0.3194999999999979, -1.038499999999999, -2.2784000000000013, -3.197400000000002, -2.3370999999999995, -2.6533000000000015, -1.2135999999999996, 0.2137999999999991, -0.5899999999999999, 0.4466999999999999, 0.3089000000000013, -0.4615000000000009, -0.4836999999999989, -1.1733000000000011, -2.4372000000000007, -0.44040000000000035, -0.44180000000000064, -0.6248000000000005, -0.08910000000000196]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gainesville18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",gainesville18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.8376796195202256

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_gai,label="1-hr")
plt.plot(hour,diff3_gai,label="3-hr")
plt.plot(hour,diff6_gai,label="6-hr")
plt.plot(hour,diff12_gai,label="12-hr")
plt.plot(hour,diff18_gai,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Fairhope, AL: 1300 UTC 5 April 2022-1300 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Fairhope_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [23.3291, 24.0771, 23.9753, 23.9737, 24.4246, 19.0186, 18.7718, 19.0171, 20.0678, 20.1876, 19.7116, 19.7796, 19.7393, 19.9232, 20.973, 21.4448, 21.9011, 22.1913, 22.44, 22.2509, 22.1212, 22.0556, 22.5883, 22.4193, 22.9804]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-AL_Fairhope_3_NE.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2268:2293]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [23.4, 23.7, 24.1, 24.2, 23.9, 19.2, 16.3, 16.8, 18.1, 18.4, 18.6, 19.2, 19.5, 19.9, 20.5, 22.2, 22.9, 22.8, 22.9, 22.8, 22.6, 22.6, 22.8, 22.7, 23.1]

# %%
difference_fai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_fai.append(temp_i-temp_crn_i)

print(difference_fai)
# Out:
# [-0.07089999999999819, 0.3771000000000022, -0.1247000000000007, -0.2262999999999984, 0.5246000000000031, -0.1814, 2.471799999999998, 2.2170999999999985, 1.9677999999999969, 1.7876000000000012, 1.1115999999999993, 0.5795999999999992, 0.23930000000000007, 0.023200000000002774, 0.472999999999999, -0.7551999999999985, -0.998899999999999, -0.6087000000000025, -0.4599999999999973, -0.5490999999999993, -0.47879999999999967, -0.5444000000000031, -0.21170000000000044, -0.2806999999999995, -0.11960000000000193]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
fairhope1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",fairhope1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 0.9712588513882378

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_fai, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Fairhope_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2266:2291]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [23.3902, 23.7288, 24.1619, 23.9613, 25.3132, 22.811, 18.5533, 19.3471, 21.5656, 21.5318, 20.8962, 19.7189, 19.7757, 20.2736, 20.3203, 20.658, 21.8456, 21.8968, 21.9147, 22.0895, 22.235, 22.1206, 21.7163, 21.4787, 22.9116]

# %%
diff3_fai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_fai.append(temp_i-temp_crn_i)

print(diff3_fai)
# Out:
# [-0.009799999999998477, 0.02880000000000038, 0.061899999999997846, -0.2386999999999979, 1.4131999999999998, 3.6110000000000007, 2.2532999999999994, 2.5471000000000004, 3.4655999999999985, 3.131800000000002, 2.296199999999999, 0.5189000000000021, 0.2757000000000005, 0.3735999999999997, -0.17970000000000041, -1.541999999999998, -1.0543999999999976, -0.9032000000000018, -0.9852999999999987, -0.7104999999999997, -0.365000000000002, -0.4794000000000018, -1.0837000000000003, -1.2212999999999994, -0.18840000000000146]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
fairhope3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",fairhope3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.5889233883356364

# %%
#6 hr hrrr:
with open('hrrr_f06_Fairhope_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.8617, 23.8339, 23.6764, 23.1228, 24.7735, 24.1222, 20.1043, 23.1264, 19.0653, 19.9948, 20.4247, 22.0611, 21.0062, 20.3848, 20.898, 21.2592, 21.7523, 21.8198, 21.6963, 21.9658, 21.591, 21.6272, 21.705, 22.1811, 22.2583]

# %%
diff6_fai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_fai.append(temp_i-temp_crn_i)

print(diff6_fai)
# Out:
# [-0.5382999999999996, 0.13390000000000057, -0.4236000000000004, -1.0771999999999977, 0.8734999999999999, 4.9222, 3.804299999999998, 6.3264, 0.9652999999999992, 1.5948000000000029, 1.8247, 2.8611000000000004, 1.5061999999999998, 0.4847999999999999, 0.3979999999999997, -0.9407999999999994, -1.1476999999999968, -0.9802, -1.2036999999999978, -0.8341999999999992, -1.0090000000000003, -0.972800000000003, -1.0950000000000024, -0.5188999999999986, -0.841700000000003]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
fairhope6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",fairhope6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 2.0807337993121564

# %%
#12 hr hrrr:
with open('hrrr_f12_Fairhope_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2257:2282]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.5171, 23.2272, 23.9501, 24.237, 24.1764, 24.304, 23.609, 19.6933, 20.3877, 21.4915, 19.9144, 20.5953, 21.8693, 21.756, 21.8265, 21.7925, 21.8142, 21.7831, 21.7139, 21.7131, 21.6965, 21.7635, 21.9765, 21.9058, 22.2254]
# 25

# %%
diff12_fai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_fai.append(temp_i-temp_crn_i)

print(diff12_fai)
# Out:
# [-0.8828999999999994, -0.47279999999999944, -0.14990000000000236, 0.036999999999999034, 0.2764000000000024, 5.103999999999999, 7.309000000000001, 2.8933, 2.2876999999999974, 3.0915, 1.3143999999999991, 1.3953000000000024, 2.369299999999999, 1.8560000000000016, 1.3264999999999993, -0.40749999999999886, -1.085799999999999, -1.0168999999999997, -1.1860999999999997, -1.0869, -0.9035000000000011, -0.8365000000000009, -0.8234999999999992, -0.7942, -0.8746000000000009]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
fairhope12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",fairhope12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 2.251997404172571

# %%
#18 hr hrrr:
with open('hrrr_f18_Fairhope_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2251:2276]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [22.3283, 22.3575, 23.6218, 23.5285, 22.6502, 17.9283, 17.4195, 18.524, 18.5341, 18.6526, 20.0379, 18.7592, 20.7489, 19.0888, 21.51, 21.5342, 21.3339, 21.6635, 21.7038, 21.2642, 21.3128, 21.3846, 21.6707, 21.8502, 22.5734]

# %%
diff18_fai = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_fai.append(temp_i-temp_crn_i)

print(diff18_fai)
# Out:
# [-1.0716999999999999, -1.3424999999999976, -0.47820000000000107, -0.6714999999999982, -1.249799999999997, -1.2716999999999992, 1.1194999999999986, 1.7240000000000002, 0.43409999999999727, 0.25260000000000105, 1.437899999999999, -0.4407999999999994, 1.248899999999999, -0.8111999999999995, 1.0100000000000016, -0.6658000000000008, -1.5660999999999987, -1.1365000000000016, -1.1961999999999975, -1.5358000000000018, -1.2872000000000021, -1.2154000000000025, -1.1293000000000006, -0.8497999999999983, -0.526600000000002]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
fairhope18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",fairhope18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.0986018996888725

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_fai,label="1-hr")
plt.plot(hour,diff3_fai,label="3-hr")
plt.plot(hour,diff6_fai,label="6-hr")
plt.plot(hour,diff12_fai,label="12-hr")
plt.plot(hour,diff18_fai,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Selma, AL: 1300 UTC 5 April 2022-1300 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Selma_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    
#Air Temp CRN:
with open('CRNH0203-2022-AL_Selma_13_WNW.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2268:2293]

    print(temp)
    print(len(temp))
    print(temp_crn)
    print(len(temp_crn))
#full time period is [2015:2112]
difference_sel = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_sel.append(temp_i-temp_crn_i)

print(difference_sel)
print(len(difference_sel))
# Out:
# [18.9541, 19.8271, 22.0378, 20.9112, 21.1746, 20.5811, 20.3968, 20.8296, 20.3803, 20.7501, 20.0866, 18.4046, 17.4893, 16.7357, 16.223, 17.6948, 18.1511, 18.3788, 19.0025, 19.6884, 19.9962, 20.3681, 20.6508, 21.1068, 22.0429]
# 25
# [16.5, 16.8, 18.5, 19.6, 18.7, 18.1, 17.8, 18.5, 19.3, 19.8, 19.8, 18.9, 18.2, 17.9, 17.7, 17.3, 18.5, 19.4, 19.5, 19.4, 19.3, 19.5, 19.9, 20.3, 20.6]
# 25
# [2.4541000000000004, 3.027100000000001, 3.5378000000000007, 1.3111999999999995, 2.4746000000000024, 2.481099999999998, 2.596799999999998, 2.3295999999999992, 1.0802999999999976, 0.9500999999999991, 0.28659999999999997, -0.49540000000000006, -0.7106999999999992, -1.1642999999999972, -1.4770000000000003, 0.39480000000000004, -0.34890000000000043, -1.0212000000000003, -0.4974999999999987, 0.2884000000000029, 0.696200000000001, 0.8680999999999983, 0.7508000000000017, 0.8067999999999991, 1.442899999999998]
# 25

# %%
# temp[17]=None
# temp[18]=None
# temp[19]=None
# temp[20]=None

# temp_crn[17]=None
# temp_crn[18]=None
# temp_crn[19]=None
# temp_crn[20]=None

# difference_sel[17]=None
# difference_sel[18]=None
# difference_sel[19]=None
# difference_sel[20]=None
# print(temp)
# print(temp_crn)
# print(difference_sel)

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_sel, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Selma_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2266:2291]

# #Air Temp CRN:
# with open('CRNH0203-2022-AL_Selma_13_WNW.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[1941:1966]

    print(temp)
#     print(len(temp))
#     print(temp_crn)
#     print(len(temp_crn))
#full time period is [2015:2112]
diff3_sel = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_sel.append(temp_i-temp_crn_i)

print(diff3_sel)
print(len(diff3_sel))
# Out:
# [17.8902, 19.6663, 19.5994, 20.8363, 21.1257, 22.3735, 21.3658, 22.1596, 20.6906, 20.5318, 20.0212, 19.0314, 17.7757, 17.0236, 16.5078, 17.158, 17.1581, 18.1468, 18.8522, 19.027, 19.5475, 19.9331, 20.4038, 20.7912, 21.9741]
# [1.3902, 2.866299999999999, 1.0993999999999993, 1.2363, 2.425699999999999, 4.2734999999999985, 3.5657999999999994, 3.659600000000001, 1.3905999999999992, 0.7317999999999998, 0.22119999999999962, 0.13140000000000285, -0.4242999999999988, -0.8764000000000003, -1.1921999999999997, -0.14199999999999946, -1.341899999999999, -1.2531999999999996, -0.6478000000000002, -0.37299999999999756, 0.24749999999999872, 0.4330999999999996, 0.5038000000000018, 0.4911999999999992, 1.3740999999999985]
# 25

# %%
# temp[17]=None
# temp[18]=None
# temp[19]=None
# temp[20]=None

# temp_crn[17]=None
# temp_crn[18]=None
# temp_crn[19]=None
# temp_crn[20]=None

# diff3_sel[17]=None
# diff3_sel[18]=None
# diff3_sel[19]=None
# diff3_sel[20]=None
# print(temp)
# print(temp_crn)
# print(diff3_sel)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-6, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 6, color='green', alpha=0.2, lw=0)
# plt.axvspan(6, 14, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# selma3 = math.sqrt(MSE)
# print("RSME 3-hr 48-hr HRRR vs CRN :",selma3)

# %%
#6 hr hrrr:
with open('hrrr_f06_Selma_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2263:2288]
# #Air Temp CRN:
# with open('CRNH0203-2022-AL_Selma_13_WNW.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[1941:1966]
print(temp)
#     print(len(temp))
#     print(temp_crn)
#     print(len(temp_crn))
#full time period is [2015:2112]
diff6_sel = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_sel.append(temp_i-temp_crn_i)

print(diff6_sel)
print(len(diff6_sel))
# Out:
# [17.4242, 18.6464, 20.4264, 19.5603, 18.2735, 19.3722, 20.7918, 21.5639, 21.5653, 22.2448, 21.2372, 19.1236, 18.3187, 18.1973, 17.398, 16.4467, 16.3148, 16.9448, 17.3213, 18.6533, 18.466, 19.0022, 19.455, 19.8686, 21.0708]
# [0.924199999999999, 1.8463999999999992, 1.926400000000001, -0.039699999999999847, -0.42650000000000077, 1.272199999999998, 2.991799999999998, 3.0639000000000003, 2.2653, 2.4448000000000008, 1.4372000000000007, 0.22360000000000113, 0.11870000000000047, 0.2972999999999999, -0.3019999999999996, -0.8533000000000008, -2.1851999999999983, -2.455199999999998, -2.178699999999999, -0.746699999999997, -0.8339999999999996, -0.4978000000000016, -0.4450000000000003, -0.4314, 0.470799999999997]
# 25

# %%
# temp[17]=None
# temp[18]=None
# temp[19]=None
# temp[20]=None

# temp_crn[17]=None
# temp_crn[18]=None
# temp_crn[19]=None
# temp_crn[20]=None

# diff6_sel[17]=None
# diff6_sel[18]=None
# diff6_sel[19]=None
# diff6_sel[20]=None
# print(temp)
# print(temp_crn)
# print(diff6_sel)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-6, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 6, color='green', alpha=0.2, lw=0)
# plt.axvspan(6, 14, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# selma6 = math.sqrt(MSE)
# print("RSME 6-hr 48-hr HRRR vs CRN :",selma6)

# %%
#12 hr hrrr:
with open('hrrr_f12_Selma_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2257:2282]
# #Air Temp CRN:
# with open('CRNH0203-2022-AL_Selma_13_WNW.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[1941:1966]

print(temp)
#     print(len(temp))
#     print(temp_crn)
#     print(len(temp_crn))
#full time period is [2015:2112]
diff12_sel = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_sel.append(temp_i-temp_crn_i)

print(diff12_sel)
print(len(diff12_sel))
# Out:
# [18.0171, 19.3522, 20.6376, 19.987, 20.9264, 19.554, 19.0465, 20.8183, 21.8877, 20.8665, 20.4144, 19.0328, 19.1193, 18.8185, 18.139, 18.605, 17.6267, 18.0331, 17.8389, 17.9006, 18.1965, 18.6385, 19.3515, 19.2183, 21.0379]
# [1.5170999999999992, 2.552199999999999, 2.137599999999999, 0.3869999999999969, 2.2264000000000017, 1.453999999999997, 1.246500000000001, 2.3183000000000007, 2.587699999999998, 1.0664999999999978, 0.6143999999999998, 0.13280000000000314, 0.9192999999999998, 0.9185000000000016, 0.43900000000000006, 1.3049999999999997, -0.8733000000000004, -1.3668999999999976, -1.6611000000000011, -1.4993999999999978, -1.1035000000000004, -0.8614999999999995, -0.5484999999999971, -1.0817000000000014, 0.43789999999999907]
# 25

# %%
# temp[17]=None
# temp[18]=None
# temp[19]=None
# temp[20]=None

# temp_crn[17]=None
# temp_crn[18]=None
# temp_crn[19]=None
# temp_crn[20]=None

# diff12_sel[17]=None
# diff12_sel[18]=None
# diff12_sel[19]=None
# diff12_sel[20]=None
# print(temp)
# print(temp_crn)
# print(diff12_sel)

# %%
# difference12 = []

# zip_object = zip(temp, temp_crn)
# for temp_i, temp_crn_i in zip_object:
#     difference12.append(temp_i-temp_crn_i)

# print(difference12)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-6, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 6, color='green', alpha=0.2, lw=0)
# plt.axvspan(6, 14, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# selma12 = math.sqrt(MSE)
# print("RSME 12-hr 48-hr HRRR vs CRN :",selma12)

# %%
#18 hr hrrr:
with open('hrrr_f18_Selma_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2251:2276]
    
# #Air Temp CRN:
# with open('CRNH0203-2022-AL_Selma_13_WNW.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[1941:1966]

print(temp)
#     print(len(temp))
#     print(temp_crn)
#     print(len(temp_crn))
#full time period is [2015:2112]
diff18_sel = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_sel.append(temp_i-temp_crn_i)

print(diff18_sel)
print(len(diff18_sel))
# Out:
# [17.9533, 19.42, 20.0593, 20.466, 19.2752, 20.0533, 18.9195, 20.4615, 20.4716, 20.0901, 20.9129, 18.6967, 17.3739, 17.8388, 18.385, 18.1592, 17.7089, 18.351, 18.8913, 19.2642, 19.5003, 20.3846, 20.1707, 20.4127, 21.3234]
# [1.4532999999999987, 2.620000000000001, 1.5593000000000004, 0.8659999999999997, 0.5752000000000024, 1.9532999999999987, 1.1194999999999986, 1.961500000000001, 1.171599999999998, 0.2900999999999989, 1.1128999999999998, -0.2032999999999987, -0.8261000000000003, -0.06119999999999948, 0.6850000000000023, 0.8591999999999977, -0.7911000000000001, -1.0489999999999995, -0.6086999999999989, -0.1357999999999997, 0.2002999999999986, 0.8845999999999989, 0.2707000000000015, 0.11270000000000024, 0.723399999999998]
# 25

# %%
# temp[17]=None
# temp[18]=None
# temp[19]=None
# temp[20]=None

# temp_crn[17]=None
# temp_crn[18]=None
# temp_crn[19]=None
# temp_crn[20]=None

# diff18_sel[17]=None
# diff18_sel[18]=None
# diff18_sel[19]=None
# diff18_sel[20]=None
# print(temp)
# print(temp_crn)
# print(diff18_sel)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-6, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 6, color='green', alpha=0.2, lw=0)
# plt.axvspan(6, 14, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# selma18 = math.sqrt(MSE)
# print("RSME 18-hr 48-hr HRRR vs CRN :",selma18)

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_sel,label="1-hr")
plt.plot(hour,diff3_sel,label="3-hr")
plt.plot(hour,diff6_sel,label="6-hr")
plt.plot(hour,diff12_sel,label="12-hr")
plt.plot(hour,diff18_sel,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Bowling Green, KY: 1500 UTC 5 April 2022-1500 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Bowling Green_KY.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2270:2295]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [13.9753, 15.4112, 12.8621, 13.2061, 13.3968, 12.7671, 12.8803, 13.2501, 13.6491, 12.4671, 12.4268, 12.1732, 10.7855, 10.0073, 10.9011, 9.50381, 9.5025, 10.9384, 11.4337, 11.5556, 11.7758, 12.2318, 12.7304, 14.2694, 14.3647]

# %%
# hour=[]
# for i in range(-8,17,1):
#     hour.append(i)
#     i+=1
# print(len(hour))

# %%
#Air Temp CRN:
with open('CRNH0203-2022-KY_Bowling_Green_21_NNE.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2270:2295]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [12.1, 11.9, 12.0, 12.4, 12.2, 11.9, 12.2, 12.5, 12.4, 12.3, 11.9, 11.6, 10.7, 9.9, 10.3, 10.5, 10.4, 10.8, 11.1, 11.0, 11.2, 11.2, 12.1, 12.8, 13.5]

# %%
difference_bow = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_bow.append(temp_i-temp_crn_i)

print(difference_bow)
# Out:
# [1.875300000000001, 3.5111999999999988, 0.8620999999999999, 0.8060999999999989, 1.1968000000000014, 0.8670999999999989, 0.6803000000000008, 0.7500999999999998, 1.2491000000000003, 0.16709999999999958, 0.5267999999999997, 0.5731999999999999, 0.08550000000000146, 0.1073000000000004, 0.6010999999999989, -0.9961900000000004, -0.8975000000000009, 0.13839999999999897, 0.33370000000000033, 0.5556000000000001, 0.575800000000001, 1.0318000000000005, 0.6303999999999998, 1.4693999999999985, 0.8646999999999991]

# %%
# temp[6]=None
# temp_crn[6]=None
# difference_bow[6]=None

# print(temp)
# print(temp_crn)
# print(difference_bow)

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_bow, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# bowling1 = math.sqrt(MSE)
# print("RSME 1-hr 48-hr HRRR vs CRN :",bowling1)

# %%
#3 hr hrrr:
with open('hrrr_f03_Bowling Green_KY.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    #temp=temp[2015:2063]
    print(temp)
# with open('CRNH0203-2022-KY_Bowling_Green_21_NNE.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[2136:2161]
#     print(temp_crn)
#     #print(len(temp))
# #full time period is [2015:2112]
# Out:
# [14.9119, 15.0238, 15.0007, 14.311, 12.6158, 13.2846, 12.8156, 12.5318, 13.2087, 12.8439, 11.6507, 10.2736, 11.5078, 10.658, 9.78305, 10.7718, 10.6647, 9.21451, 10.11, 10.8706, 11.5913, 12.1662, 12.7241, 13.6093, 14.7339]

# %%
diff3_bow = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_bow.append(temp_i-temp_crn_i)

print(diff3_bow)
# Out:
# [2.8118999999999996, 3.1237999999999992, 3.0007, 1.9109999999999996, 0.41580000000000084, 1.384599999999999, 0.6156000000000006, 0.031800000000000495, 0.8087, 0.5438999999999989, -0.24929999999999986, -1.3263999999999996, 0.8078000000000003, 0.7579999999999991, -0.5169500000000014, 0.2718000000000007, 0.2646999999999995, -1.58549, -0.9900000000000002, -0.1294000000000004, 0.3913000000000011, 0.9662000000000006, 0.6241000000000003, 0.8092999999999986, 1.2339000000000002]

# %%
# temp[6]=None
# temp_crn[6]=None
# diff3_bow[6]=None

# print(temp)
# print(temp_crn)
# print(diff3_bow)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# bowling3 = math.sqrt(MSE)
# print("RSME 3-hr 48-hr HRRR vs CRN :",bowling3)

# %%
#6 hr hrrr:
with open('hrrr_f06_Bowling Green_KY.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
# with open('CRNH0203-2022-KY_Bowling_Green_21_NNE.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[2136:2161]
#     print(temp_crn)
#     #print(len(temp))
# #full time period is [2015:2112]
# Out:
# [14.8014, 17.0603, 16.5235, 15.2472, 12.7918, 12.6264, 12.1903, 12.6823, 12.3622, 12.1236, 11.8812, 11.7598, 12.023, 11.9467, 9.43979, 9.81982, 9.50876, 9.59079, 9.96597, 10.2522, 10.5175, 11.3061, 12.0708, 13.4903, 13.6743]

# %%
diff6_bow = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_bow.append(temp_i-temp_crn_i)

print(diff6_bow)
# Out:
# [2.7013999999999996, 5.160300000000001, 4.5234999999999985, 2.847199999999999, 0.591800000000001, 0.7263999999999999, -0.00969999999999871, 0.18229999999999968, -0.03780000000000072, -0.176400000000001, -0.018800000000000594, 0.1598000000000006, 1.3230000000000004, 2.0466999999999995, -0.8602100000000004, -0.68018, -0.8912399999999998, -1.2092100000000006, -1.1340299999999992, -0.7477999999999998, -0.6824999999999992, 0.10610000000000142, -0.02919999999999945, 0.6902999999999988, 0.17430000000000057]

# %%
# temp[6]=None
# temp_crn[6]=None
# diff6_bow[6]=None

# print(temp)
# print(temp_crn)
# print(diff6_bow)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# bowling6 = math.sqrt(MSE)
# print("RSME 6-hr 48-hr HRRR vs CRN :",bowling6)

# %%
#12 hr hrrr:
with open('hrrr_f12_Bowling Green_KY.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2259:2284]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
# with open('CRNH0203-2022-KY_Bowling_Green_21_NNE.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[2136:2161]
#     print(temp_crn)
# #full time period is [2015:2112]
# Out:
# [15.2626, 17.112, 16.4264, 14.2415, 13.484, 14.5058, 13.3252, 13.304, 12.3519, 12.3453, 10.5568, 9.75601, 9.07651, 8.79248, 9.68918, 9.09561, 9.02637, 9.2756, 9.1965, 9.76346, 10.1015, 10.8433, 11.7254, 13.0771, 13.7357]
# 25

# %%
diff12_bow = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_bow.append(temp_i-temp_crn_i)

print(diff12_bow)
# Out:
# [3.162600000000001, 5.211999999999998, 4.426400000000001, 1.8415, 1.2840000000000007, 2.6058000000000003, 1.1252000000000013, 0.8040000000000003, -0.04809999999999981, 0.04529999999999923, -1.3431999999999995, -1.8439899999999998, -1.6234899999999985, -1.107520000000001, -0.6108200000000004, -1.4043899999999994, -1.3736300000000004, -1.5244, -1.9034999999999993, -1.2365399999999998, -1.0984999999999996, -0.3567, -0.37459999999999916, 0.277099999999999, 0.23569999999999958]

# %%
# temp[6]=None
# temp_crn[6]=None
# diff12_bow[6]=None

# print(temp)
# print(temp_crn)
# print(diff12_bow)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# bowling12 = math.sqrt(MSE)
# print("RSME 12-hr 48-hr HRRR vs CRN :",bowling12)

# %%
#18 hr hrrr:
with open('hrrr_f18_Bowling Green_KY.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2253:2278]
    print(temp)
# with open('CRNH0203-2022-KY_Bowling_Green_21_NNE.txt') as f:
#     lst=[line.split()[9] for line in f]
#     #print(lst)
#     temp_crn=[]
#     for i in lst:
#         new=i.replace(',',"")
#         temp_crn.append(new)
#     temp_crn=[float(x) for x in temp_crn]
#     temp_crn=temp_crn[2136:2161]
#     print(temp_crn)
#     #print(len(temp))
# #full time period is [2015:2112]
# Out:
# [15.4968, 15.7785, 17.0877, 13.8033, 14.357, 14.4615, 13.4091, 13.6526, 14.6004, 14.0092, 12.0614, 10.4638, 10.0725, 9.47174, 9.45886, 10.6635, 8.07883, 8.51419, 10.0003, 9.38461, 10.3582, 10.6627, 11.8234, 11.7996, 13.0787]

# %%
diff18_bow = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_bow.append(temp_i-temp_crn_i)

print(diff18_bow)
# Out:
# [3.3968000000000007, 3.878499999999999, 5.087700000000002, 1.4032999999999998, 2.157, 2.5614999999999988, 1.2091000000000012, 1.1525999999999996, 2.2004, 1.7091999999999992, 0.16140000000000043, -1.1361999999999988, -0.6274999999999995, -0.42825999999999986, -0.8411400000000011, 0.16350000000000087, -2.3211700000000004, -2.2858100000000015, -1.0997000000000003, -1.6153899999999997, -0.8417999999999992, -0.5373000000000001, -0.2766000000000002, -1.0004000000000008, -0.42130000000000045]

# %%
# temp[6]=None
# temp_crn[6]=None
# diff18_bow[6]=None

# print(temp)
# print(temp_crn)
# print(diff18_bow)

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
# MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
# bowling18 = math.sqrt(MSE)
# print("RSME 18-hr 48-hr HRRR vs CRN :",bowling18)

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_bow,label="1-hr")
plt.plot(hour,diff3_bow,label="3-hr")
plt.plot(hour,diff6_bow,label="6-hr")
plt.plot(hour,diff12_bow,label="12-hr")
plt.plot(hour,diff18_bow,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Gadsden, AL: 1500 UTC 5 April 2022-1500 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Gadsden_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2270:2295]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [10.9128, 10.6612, 13.4246, 13.4561, 15.2718, 15.3296, 16.0678, 16.6876, 17.2741, 16.8421, 15.3643, 14.2982, 13.598, 12.8198, 13.4636, 13.4413, 13.6275, 13.8134, 14.3712, 14.4931, 14.3383, 14.2943, 15.2929, 15.9569, 16.8022]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-AL_Gadsden_19_N.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2270:2295]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [11.0, 11.3, 11.6, 12.4, 14.0, 16.9, 17.7, 18.1, 18.4, 18.3, 17.2, 14.9, 13.3, 12.1, 13.0, 13.0, 13.6, 13.9, 14.4, 14.6, 15.0, 15.4, 16.0, 16.9, 17.6]

# %%
difference_gad = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_gad.append(temp_i-temp_crn_i)

print(difference_gad)
# Out:
# [-0.08719999999999928, -0.6388000000000016, 1.8246000000000002, 1.056099999999999, 1.2718000000000007, -1.5703999999999994, -1.632200000000001, -1.4124000000000017, -1.125899999999998, -1.4579000000000022, -1.8356999999999992, -0.6018000000000008, 0.29800000000000004, 0.7198000000000011, 0.46359999999999957, 0.4413, 0.027499999999999858, -0.08660000000000068, -0.02880000000000038, -0.10689999999999955, -0.6616999999999997, -1.1057000000000006, -0.7071000000000005, -0.9430999999999994, -0.7978000000000023]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gadsden1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",gadsden1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.008985161238757

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_gad, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
#3 hr hrrr:
with open('hrrr_f03_Gadsden_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.8494, 11.3363, 12.6882, 14.9985, 16.8658, 19.6596, 17.5656, 18.2818, 16.8962, 16.0314, 15.0882, 14.0861, 13.0703, 12.8455, 13.2831, 13.7718, 13.8522, 13.902, 14.1725, 14.6206, 14.8413, 15.0412, 15.2241, 16.2968, 17.3589]

# %%
diff3_gad = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_gad.append(temp_i-temp_crn_i)

print(diff3_gad)
# Out:
# [0.8493999999999993, 0.03629999999999889, 1.0882000000000005, 2.5984999999999996, 2.8658, 2.7596000000000025, -0.1343999999999994, 0.18179999999999907, -1.5037999999999982, -2.2685999999999993, -2.111799999999999, -0.8139000000000003, -0.22970000000000113, 0.7454999999999998, 0.28309999999999924, 0.7718000000000007, 0.2522000000000002, 0.0019999999999988916, -0.22750000000000092, 0.02059999999999995, -0.15869999999999962, -0.35880000000000045, -0.7759, -0.6031999999999975, -0.24110000000000298]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gadsden3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",gadsden3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 1.259311793322051

# %%
#6 hr hrrr:
with open('hrrr_f06_Gadsden_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2265:2290]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.2389, 12.2478, 12.8985, 18.1847, 17.9793, 18.8764, 18.0653, 18.3698, 17.6122, 16.6861, 15.1312, 14.3848, 13.773, 12.8842, 13.6273, 13.7573, 13.9463, 14.0908, 14.5285, 14.8147, 14.955, 14.9936, 15.7583, 16.1153, 18.0493]

# %%
diff6_gad = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_gad.append(temp_i-temp_crn_i)

print(diff6_gad)
# Out:
# [0.23889999999999922, 0.9477999999999991, 1.2985000000000007, 5.784699999999999, 3.9792999999999985, 1.9764000000000017, 0.3653000000000013, 0.26980000000000004, -0.7877999999999972, -1.613900000000001, -2.0687999999999995, -0.5152000000000001, 0.472999999999999, 0.7842000000000002, 0.6273, 0.7573000000000008, 0.34630000000000116, 0.19079999999999941, 0.12849999999999895, 0.21470000000000056, -0.04499999999999993, -0.40639999999999965, -0.2416999999999998, -0.7846999999999973, 0.44929999999999737]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gadsden6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",gadsden6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 1.6357263318782882

# %%
#12 hr hrrr:
with open('hrrr_f12_Gadsden_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2259:2284]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [11.5751, 11.987, 13.3014, 13.429, 15.7965, 18.7558, 18.8877, 19.3665, 18.9144, 17.6578, 16.2443, 14.8185, 13.764, 12.6675, 12.8142, 12.5956, 12.4014, 12.5256, 13.3215, 14.0135, 14.4765, 14.7808, 15.2254, 16.2021, 17.4232]
# 25

# %%
diff12_gad = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_gad.append(temp_i-temp_crn_i)

print(diff12_gad)
# Out:
# [0.5751000000000008, 0.6869999999999994, 1.7013999999999996, 1.029, 1.7965, 1.8558000000000021, 1.1876999999999995, 1.266499999999997, 0.514400000000002, -0.642199999999999, -0.9557000000000002, -0.08150000000000013, 0.46399999999999864, 0.5675000000000008, -0.1858000000000004, -0.40440000000000076, -1.198599999999999, -1.3743999999999996, -1.0785, -0.5864999999999991, -0.5235000000000003, -0.6192000000000011, -0.7745999999999995, -0.6978999999999971, -0.17680000000000007]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gadsden12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",gadsden12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 0.9671270466696709

# %%
#18 hr hrrr:
with open('hrrr_f18_Gadsden_AL.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2253:2278]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [12.1218, 12.591, 13.2752, 14.0533, 16.107, 17.649, 18.8466, 16.8401, 17.0379, 17.1342, 16.3114, 16.6513, 14.3225, 13.5342, 13.7714, 13.476, 12.8288, 12.2642, 12.4378, 12.2596, 13.2957, 13.4752, 14.1984, 15.6121, 17.0787]

# %%
diff18_gad = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_gad.append(temp_i-temp_crn_i)

print(diff18_gad)
# Out:
# [1.1218000000000004, 1.2909999999999986, 1.6752000000000002, 1.6532999999999998, 2.1069999999999993, 0.7490000000000023, 1.1465999999999994, -1.2599000000000018, -1.362099999999998, -1.1658000000000008, -0.8886000000000003, 1.7512999999999987, 1.022499999999999, 1.4342000000000006, 0.7713999999999999, 0.47600000000000087, -0.7712000000000003, -1.6357999999999997, -1.962200000000001, -2.340399999999999, -1.7043, -1.9248000000000012, -1.8016000000000005, -1.2878999999999987, -0.5213000000000001]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
gadsden18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",gadsden18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 1.4386997957878496

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_gad,label="1-hr")
plt.plot(hour,diff3_gad,label="3-hr")
plt.plot(hour,diff6_gad,label="6-hr")
plt.plot(hour,diff12_gad,label="12-hr")
plt.plot(hour,diff18_gad,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <font size="3">Newton, GA: 1800 UTC 5 April 2022-1800 UTC 6 April 2022</font>

# %%
#1 hr hrrr:
with open('hrrr_f01_Newton_GA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2273:2298]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [26.8936, 26.9593, 27.0796, 20.6303, 20.7501, 19.1491, 18.0921, 17.3643, 16.8607, 16.9105, 17.5073, 17.2761, 17.7538, 18.315, 18.5009, 19.1212, 19.8056, 20.0883, 21.5443, 23.2304, 23.7694, 24.5522, 25.7326, 25.9385, 26.1719]

# %%
#Air Temp CRN:
with open('CRNH0203-2022-GA_Newton_11_SW.txt') as f:
    lst=[line.split()[9] for line in f]
    #print(lst)
    temp_crn=[]
    for i in lst:
        new=i.replace(',',"")
        temp_crn.append(new)
    temp_crn=[float(x) for x in temp_crn]
    temp_crn=temp_crn[2273:2298]
    print(temp_crn)
    #print(len(temp_crn))
    # print(temp_crn[2124])
# Out:
# [25.7, 27.0, 25.7, 17.5, 17.1, 16.9, 17.0, 17.1, 17.2, 17.2, 17.0, 17.2, 17.6, 18.1, 18.8, 19.7, 20.4, 21.1, 21.4, 22.2, 23.2, 24.5, 25.5, 26.7, 27.4]

# %%
difference_newt = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    difference_newt.append(temp_i-temp_crn_i)

print(difference_newt)
# Out:
# [1.1936, -0.04070000000000107, 1.3796, 3.1302999999999983, 3.6500999999999983, 2.249100000000002, 1.0920999999999985, 0.26429999999999865, -0.33929999999999794, -0.2895000000000003, 0.5073000000000008, 0.07610000000000028, 0.15379999999999683, 0.21499999999999986, -0.29909999999999926, -0.5787999999999975, -0.5944000000000003, -1.0117000000000012, 0.1443000000000012, 1.0304000000000002, 0.5694000000000017, 0.052199999999999136, 0.23260000000000147, -0.7614999999999981, -1.2280999999999977]

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

ax1 = plt.subplot()
plt.grid()
ax1.grid(True, which='both')
l1, = ax1.plot(hour,temp)
l3, = ax1.plot(hour,temp_crn, color='red')
ax1.set_ylim(0, 30)
plt.yticks(np.arange(0,31,2.5))
ax2 = ax1.twinx()
l2, = ax2.plot(hour,difference_newt, color='orange')
ax2.set_ylim(-10, 10)
plt.axhline(y=0, color='black', linestyle='dashed')
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#ax2.yticks(np.arange(-6, 11, 2.0))
plt.title("1-hr HRRR vs. CRN")
plt.ylabel("Difference in Air Temperature (C)")
ax1.set_ylabel("Air Temperature (C)")
ax1.set_xlabel("Time Relative to Event Passage")

plt.legend([l1, l3,l2], ["HRRR", "CRN","Difference"])

plt.show()

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("1-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonga1 = math.sqrt(MSE)
print("RSME 1-hr 48-hr HRRR vs CRN :",newtonga1)
# Out:
# RSME 1-hr 48-hr HRRR vs CRN : 1.2435048704367824

# %%
#3 hr hrrr:
with open('hrrr_f03_Newton_GA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2271:2296]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [26.4985, 26.8033, 26.4096, 27.8781, 20.6568, 20.9587, 19.4064, 18.2757, 17.3361, 17.4453, 17.2205, 17.5956, 17.6468, 17.9147, 17.652, 17.61, 18.3081, 18.9663, 20.0412, 22.0366, 24.2968, 25.3589, 26.0537, 26.5118, 27.1513]

# %%
diff3_newt = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff3_newt.append(temp_i-temp_crn_i)

print(diff3_newt)
# Out:
# [0.7985000000000007, -0.19669999999999987, 0.7096000000000018, 10.3781, 3.556799999999999, 4.058700000000002, 2.4064000000000014, 1.175699999999999, 0.136099999999999, 0.2453000000000003, 0.22050000000000125, 0.39560000000000173, 0.04679999999999751, -0.18530000000000157, -1.1479999999999997, -2.09, -2.091899999999999, -2.133700000000001, -1.3587999999999987, -0.16339999999999932, 1.0968000000000018, 0.8588999999999984, 0.5536999999999992, -0.18819999999999837, -0.24869999999999948]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("3-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonga3 = math.sqrt(MSE)
print("RSME 3-hr 48-hr HRRR vs CRN :",newtonga3)
# Out:
# RSME 3-hr 48-hr HRRR vs CRN : 2.563859012504393

# %%
#6 hr hrrr:
with open('hrrr_f06_Newton_GA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2268:2293]
    #temp=temp[2015:2063]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [27.3722, 27.1043, 27.3139, 26.3778, 19.9948, 20.1122, 19.7486, 19.0687, 19.1348, 18.3355, 17.8217, 17.5648, 16.8823, 17.6338, 17.8408, 17.6535, 17.5647, 18.0175, 18.6811, 21.0708, 23.7403, 25.2993, 25.4016, 26.9903, 27.4844]

# %%
diff6_newt = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff6_newt.append(temp_i-temp_crn_i)

print(diff6_newt)
# Out:
# [1.6722000000000001, 0.1042999999999985, 1.613900000000001, 8.8778, 2.8948, 3.212200000000003, 2.7485999999999997, 1.9686999999999983, 1.9347999999999992, 1.1355000000000004, 0.8216999999999999, 0.36480000000000246, -0.7177000000000007, -0.4662000000000006, -0.9591999999999992, -2.046499999999998, -2.8353, -3.082500000000003, -2.718899999999998, -1.1292000000000009, 0.540300000000002, 0.7992999999999988, -0.0984000000000016, 0.290300000000002, 0.08440000000000225]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("6-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonga6 = math.sqrt(MSE)
print("RSME 6-hr 48-hr HRRR vs CRN :",newtonga6)
# Out:
# RSME 6-hr 48-hr HRRR vs CRN : 2.476107312133301

# %%
#12 hr hrrr:
with open('hrrr_f12_Newton_GA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    temp=temp[2262:2287]
    #temp=temp[2015:2063]
    print(temp)
    print(len(temp))
#full time period is [2015:2112]
# Out:
# [25.7415, 27.6715, 28.2558, 26.9502, 22.8665, 18.9769, 18.9703, 19.1193, 19.131, 18.8265, 18.98, 18.7517, 21.5956, 21.0889, 20.5256, 19.009, 19.326, 18.2265, 18.5308, 21.0379, 23.1396, 24.2982, 25.0232, 26.2415, 25.5895]
# 25

# %%
diff12_newt = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff12_newt.append(temp_i-temp_crn_i)

print(diff12_newt)
# Out:
# [0.041499999999999204, 0.6715000000000018, 2.5558000000000014, 9.450199999999999, 5.766499999999997, 2.076900000000002, 1.9703000000000017, 2.0192999999999977, 1.931000000000001, 1.6265, 1.9800000000000004, 1.5517000000000003, 3.9955999999999996, 2.9888999999999974, 1.7256, -0.690999999999999, -1.073999999999998, -2.8735, -2.8691999999999993, -1.1620999999999988, -0.06039999999999779, -0.20179999999999865, -0.4768000000000008, -0.4585000000000008, -1.8104999999999976]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("12-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonga12 = math.sqrt(MSE)
print("RSME 12-hr 48-hr HRRR vs CRN :",newtonga12)
# Out:
# RSME 12-hr 48-hr HRRR vs CRN : 2.867931513338489

# %%
#18 hr hrrr:
with open('hrrr_f18_Newton_GA.txt') as f:
    lst=[line.split()[1] for line in f]
    temp=[]
    for i in lst:
        new=i.replace(',',"")
        temp.append(new)
    temp.pop(0)
    temp=[float(x) for x in temp]
    #print(temp.index(6.91541))
    temp=temp[2256:2281]
    print(temp)
    #print(len(temp))
#full time period is [2015:2112]
# Out:
# [25.7408, 27.2945, 26.7115, 25.8466, 18.0276, 19.5379, 19.1342, 18.3114, 18.6513, 19.385, 19.4717, 19.9589, 19.2885, 20.7663, 21.3892, 20.9378, 20.5096, 20.9832, 21.7252, 21.6984, 23.1746, 23.8287, 24.477, 25.6908, 24.3736]

# %%
diff18_newt = []

zip_object = zip(temp, temp_crn)
for temp_i, temp_crn_i in zip_object:
    diff18_newt.append(temp_i-temp_crn_i)

print(diff18_newt)
# Out:
# [0.040800000000000836, 0.2944999999999993, 1.0115000000000016, 8.346599999999999, 0.9275999999999982, 2.637900000000002, 2.1342, 1.2113999999999976, 1.4512999999999998, 2.1850000000000023, 2.4716999999999985, 2.7589000000000006, 1.6884999999999977, 2.6662999999999997, 2.589199999999998, 1.2378, 0.10960000000000036, -0.11680000000000135, 0.3252000000000024, -0.5015999999999998, -0.025399999999997647, -0.6712999999999987, -1.0229999999999997, -1.0091999999999999, -3.026399999999999]

# %%
# #plot 1-hr:
# plt.rcParams["figure.figsize"] = [9.00, 4.50]
# plt.rcParams["figure.autolayout"] = True
# #default_x_ticks= range(len(hour))
# # plt.plot(hour,temp,label="HRRR")
# # plt.plot(hour,temp_crn,label="CRN")
# plt.plot(hour,difference,color="black",label="Difference")
# #plt.xticks(default_x_ticks,hour)
# plt.title("18-hr HRRR vs. CRN Difference")
# plt.xlabel("UTC Hour")
# plt.ylabel("Air Temp (C)")
# plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
# plt.axvspan(-8, 0, color='red', alpha=0.2, lw=0)
# plt.axvspan(0, 8, color='green', alpha=0.2, lw=0)
# plt.axvspan(8, 16, color='y', alpha=0.2, lw=0)
# plt.show()

# %%
MSE = np.square(np.subtract(temp_crn,temp)).mean() 
 
newtonga18 = math.sqrt(MSE)
print("RSME 18-hr 48-hr HRRR vs CRN :",newtonga18)
# Out:
# RSME 18-hr 48-hr HRRR vs CRN : 2.3278706848104767

# %%
# hour=[]
# for i in range(-12,13,1):
#     hour.append(i)
#     i+=1
# print(len(hour))

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [9.00, 4.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_newt,label="1-hr")
plt.plot(hour,diff3_newt,label="3-hr")
plt.plot(hour,diff6_newt,label="6-hr")
plt.plot(hour,diff12_newt,label="12-hr")
plt.plot(hour,diff18_newt,label="18-hr")
plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend()
plt.show()

# %%
#plot 1-hr:
plt.rcParams["figure.figsize"] = [11.00, 5.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,difference_sal,c='royalblue',label="Salem, MO")
plt.plot(hour,difference_bat,c='darkorange',label="Batesville, AR")
plt.plot(hour,difference_laf,c='g',label="Lafayette, LA")
plt.plot(hour,difference_mon,c='r',label="Monroe, LA")
plt.plot(hour,difference_hol,c='seagreen',label="Holly Springs, MS")
plt.plot(hour,difference_new,c='brown',label="Newton, MS")
plt.plot(hour,difference_gai,c='olive',label="Gainesville, AL")
plt.plot(hour,difference_fai,c='gray',label="Fairhope, AL")
plt.plot(hour,difference_sel,c='y',label="Selma, AL")
plt.plot(hour,difference_bow,c='c',label="Bowling Green, KY")
plt.plot(hour,difference_gad,c='mediumorchid',label="Gadsden, AL")
plt.plot(hour,difference_newt,c='slateblue',label="Newton, GA")

plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("1-hr HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature (C)")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
#plot 3-hr:
plt.rcParams["figure.figsize"] = [11.00, 5.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,diff3_sal,c='royalblue',label="Salem, MO")
plt.plot(hour,diff3_bat,c='darkorange',label="Batesville, AR")
plt.plot(hour,diff3_laf,c='g',label="Lafayette, LA")
plt.plot(hour,diff3_mon,c='r',label="Monroe, LA")
plt.plot(hour,diff3_hol,c='seagreen',label="Holly Springs, MS")
plt.plot(hour,diff3_new,c='brown',label="Newton, MS")
plt.plot(hour,diff3_gai,c='olive',label="Gainesville, AL")
plt.plot(hour,diff3_fai,c='gray',label="Fairhope, AL")
plt.plot(hour,diff3_sel,c='y',label="Selma, AL")
plt.plot(hour,diff3_bow,c='c',label="Bowling Green, KY")
plt.plot(hour,diff3_gad,c='mediumorchid',label="Gadsden, AL")
plt.plot(hour,diff3_newt,c='slateblue',label="Newton, GA")


plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("3-hr HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
#plot 6-hr:
plt.rcParams["figure.figsize"] = [11.00, 5.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,diff6_sal,c='royalblue',label="Salem, MO")
plt.plot(hour,diff6_bat,c='darkorange',label="Batesville, AR")
plt.plot(hour,diff6_laf,c='g',label="Lafayette, LA")
plt.plot(hour,diff6_mon,c='r',label="Monroe, LA")
plt.plot(hour,diff6_hol,c='seagreen',label="Holly Springs, MS")
plt.plot(hour,diff6_new,c='brown',label="Newton, MS")
plt.plot(hour,diff6_gai,c='olive',label="Gainesville, AL")
plt.plot(hour,diff6_fai,c='gray',label="Fairhope, AL")
plt.plot(hour,diff6_sel,c='y',label="Selma, AL")
plt.plot(hour,diff6_bow,c='c',label="Bowling Green, KY")
plt.plot(hour,diff6_gad,c='mediumorchid',label="Gadsden, AL")
plt.plot(hour,diff6_newt,c='slateblue',label="Newton, GA")


plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("6-hr HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
#plot 3-hr:
plt.rcParams["figure.figsize"] = [11.00, 5.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,diff12_sal,c='royalblue',label="Salem, MO")
plt.plot(hour,diff12_bat,c='darkorange',label="Batesville, AR")
plt.plot(hour,diff12_laf,c='g',label="Lafayette, LA")
plt.plot(hour,diff12_mon,c='r',label="Monroe, LA")
plt.plot(hour,diff12_hol,c='seagreen',label="Holly Springs, MS")
plt.plot(hour,diff12_new,c='brown',label="Newton, MS")
plt.plot(hour,diff12_gai,c='olive',label="Gainesville, AL")
plt.plot(hour,diff12_fai,c='gray',label="Fairhope, AL")
plt.plot(hour,diff12_sel,c='y',label="Selma, AL")
plt.plot(hour,diff12_bow,c='c',label="Bowling Green, KY")
plt.plot(hour,diff12_gad,c='mediumorchid',label="Gadsden, AL")
plt.plot(hour,diff12_newt,c='slateblue',label="Newton, GA")

plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("12-hr HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
#plot 3-hr:
plt.rcParams["figure.figsize"] = [11.00, 5.50]
plt.rcParams["figure.autolayout"] = True
#default_x_ticks= range(len(hour))
# plt.plot(hour,temp,label="HRRR")
# plt.plot(hour,temp_crn,label="CRN")
plt.plot(hour,diff18_sal,c='royalblue',label="Salem, MO")
plt.plot(hour,diff18_bat,c='darkorange',label="Batesville, AR")
plt.plot(hour,diff18_laf,c='g',label="Lafayette, LA")
plt.plot(hour,diff18_mon,c='r',label="Monroe, LA")
plt.plot(hour,diff18_hol,c='seagreen',label="Holly Springs, MS")
plt.plot(hour,diff18_new,c='brown',label="Newton, MS")
plt.plot(hour,diff18_gai,c='olive',label="Gainesville, AL")
plt.plot(hour,diff18_fai,c='gray',label="Fairhope, AL")
plt.plot(hour,diff18_sel,c='y',label="Selma, AL")
plt.plot(hour,diff18_bow,c='c',label="Bowling Green, KY")
plt.plot(hour,diff18_gad,c='mediumorchid',label="Gadsden, AL")
plt.plot(hour,diff18_newt,c='slateblue',label="Newton, GA")

plt.yticks(np.arange(-12, 13, 2.0))
plt.ylim(-12, 12)
plt.title("18-hr HRRR vs. CRN Difference")
plt.xlabel("Time Relative to Event Passage")
plt.ylabel("Difference in Air Temperature")
plt.xticks(np.arange(min(hour), max(hour)+1, 1.0))
plt.axvspan(-4, 4, color='green', alpha=0.2, lw=0)
#plt.grid(axis='y')
plt.grid()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()
